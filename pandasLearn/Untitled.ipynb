# %%
import pandas as pd

# %%
s = pd.Series([1,2,3,4,5], index=['a','b','c','d','e'])

# %%
s
# Out:
# a    1
# b    2
# c    3
# d    4
# e    5
# dtype: int64

# %%
df = pd.DataFrame({'names':['sameer','asif'], 'marks':[100,99]})

# %%
df
# Out:
#     names  marks
# 0  sameer    100
# 1    asif     99

# %%
df = pd.read_csv("people-100.csv")

# %%
df
# Out:
#     Index          User Id First Name  Last Name     Sex  \
# 0       1  88F7B33d2bcf9f5     Shelby    Terrell    Male
# 1       2  f90cD3E76f1A9b9    Phillip    Summers  Female
# 2       3  DbeAb8CcdfeFC2c   Kristine     Travis    Male
# 3       4  A31Bee3c201ef58    Yesenia   Martinez    Male
# 4       5  1bA7A3dc874da3c       Lori       Todd    Male
# ..    ...              ...        ...        ...     ...
# 95     96  5eFda7caAeB260E     Dennis     Barnes  Female
# 96     97  CCbFce93d3720bE      Steve  Patterson  Female
# 97     98  2fEc528aFAF0b69     Wesley       Bray    Male
# 98     99  Adc7ad9B6e4A1Fe     Summer   Oconnell  Female
# 99    100  b8D0aD3490FC7e1     Mariah    Bernard    Male
#
#                          Email                   Phone Date of birth  \
# 0         elijah57@example.net  001-084-906-7849x73518    1945-10-26
# 1        bethany14@example.com       214.112.6044x4913    1910-03-24
# 2        bthompson@example.com            277.609.7938    1992-07-02
# ...

# %%
df.head()
# Out:
#    Index          User Id First Name Last Name     Sex  \
# 0      1  88F7B33d2bcf9f5     Shelby   Terrell    Male
# 1      2  f90cD3E76f1A9b9    Phillip   Summers  Female
# 2      3  DbeAb8CcdfeFC2c   Kristine    Travis    Male
# 3      4  A31Bee3c201ef58    Yesenia  Martinez    Male
# 4      5  1bA7A3dc874da3c       Lori      Todd    Male
#
#                         Email                   Phone Date of birth  \
# 0        elijah57@example.net  001-084-906-7849x73518    1945-10-26
# 1       bethany14@example.com       214.112.6044x4913    1910-03-24
# 2       bthompson@example.com            277.609.7938    1992-07-02
# 3   kaitlinkaiser@example.com            584.094.6111    2017-08-03
# 4  buchananmanuel@example.net       689-207-3558x7233    1938-12-01
#
#             Job Title
# 0     Games developer
# 1      Phytotherapist
# 2           Homeopath
# 3   Market researcher
# 4  Veterinary surgeon

# %%
df.tail()
# Out:
#     Index          User Id First Name  Last Name     Sex  \
# 95     96  5eFda7caAeB260E     Dennis     Barnes  Female
# 96     97  CCbFce93d3720bE      Steve  Patterson  Female
# 97     98  2fEc528aFAF0b69     Wesley       Bray    Male
# 98     99  Adc7ad9B6e4A1Fe     Summer   Oconnell  Female
# 99    100  b8D0aD3490FC7e1     Mariah    Bernard    Male
#
#                          Email                 Phone Date of birth  \
# 95         bmartin@example.org  001-095-524-2112x257    1954-07-30
# 96       latasha46@example.net      001-865-478-5157    1932-04-29
# 97        regina11@example.org    995-542-3004x76800    1994-12-28
# 98  alexiscantrell@example.org  001-273-685-6932x092    2012-04-12
# 99       pcopeland@example.org   (341)594-6554x44657    2016-11-15
#
#                 Job Title
# 95      Software engineer
# 96              Barrister
# 97         Police officer
# 98   Broadcast journalist
# 99  IT sales professional

# %%
df.describe()
# Out:
#             Index
# count  100.000000
# mean    50.500000
# std     29.011492
# min      1.000000
# 25%     25.750000
# 50%     50.500000
# 75%     75.250000
# max    100.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Index          100 non-null    int64
#  1   User Id        100 non-null    object
#  2   First Name     100 non-null    object
#  3   Last Name      100 non-null    object
#  4   Sex            100 non-null    object
#  5   Email          100 non-null    object
#  6   Phone          100 non-null    object
#  7   Date of birth  100 non-null    object
#  8   Job Title      100 non-null    object
# dtypes: int64(1), object(8)
# memory usage: 7.2+ KB

# %%
df["User Id"]
# Out:
# 0     88F7B33d2bcf9f5
# 1     f90cD3E76f1A9b9
# 2     DbeAb8CcdfeFC2c
# 3     A31Bee3c201ef58
# 4     1bA7A3dc874da3c
#            ...
# 95    5eFda7caAeB260E
# 96    CCbFce93d3720bE
# 97    2fEc528aFAF0b69
# 98    Adc7ad9B6e4A1Fe
# 99    b8D0aD3490FC7e1
# Name: User Id, Length: 100, dtype: object

# %% [markdown]
# Data Selection

# %%
type(df["User Id"])
# Out:
# pandas.core.series.Series

# %%
df[["User Id","Email"]]
# Out:
#             User Id                       Email
# 0   88F7B33d2bcf9f5        elijah57@example.net
# 1   f90cD3E76f1A9b9       bethany14@example.com
# 2   DbeAb8CcdfeFC2c       bthompson@example.com
# 3   A31Bee3c201ef58   kaitlinkaiser@example.com
# 4   1bA7A3dc874da3c  buchananmanuel@example.net
# ..              ...                         ...
# 95  5eFda7caAeB260E         bmartin@example.org
# 96  CCbFce93d3720bE       latasha46@example.net
# 97  2fEc528aFAF0b69        regina11@example.org
# 98  Adc7ad9B6e4A1Fe  alexiscantrell@example.org
# 99  b8D0aD3490FC7e1       pcopeland@example.org
#
# [100 rows x 2 columns]

# %%
df.iloc[0]
# Out:
# Index                                 1
# User Id                 88F7B33d2bcf9f5
# First Name                       Shelby
# Last Name                       Terrell
# Sex                                Male
# Email              elijah57@example.net
# Phone            001-084-906-7849x73518
# Date of birth                1945-10-26
# Job Title               Games developer
# Name: 0, dtype: object

# %%
type(df.iloc[0])
# Out:
# pandas.core.series.Series

# %%
df1 = pd.read_csv("data.csv")

# %%
df1
# Out:
#     Index          User Id First Name  Last Name     Sex  \
# 0       1  88F7B33d2bcf9f5     Shelby    Terrell    Male
# 1       2  f90cD3E76f1A9b9    Phillip    Summers  Female
# 2       3  DbeAb8CcdfeFC2c   Kristine     Travis    Male
# 3       4  A31Bee3c201ef58    Yesenia   Martinez    Male
# 4       5  1bA7A3dc874da3c       Lori       Todd    Male
# ..    ...              ...        ...        ...     ...
# 95     96  5eFda7caAeB260E     Dennis     Barnes  Female
# 96     97  CCbFce93d3720bE      Steve  Patterson  Female
# 97     98  2fEc528aFAF0b69     Wesley       Bray    Male
# 98     99  Adc7ad9B6e4A1Fe     Summer   Oconnell  Female
# 99    100  b8D0aD3490FC7e1     Mariah    Bernard     NaN
#
#                          Email                   Phone Date of birth  \
# 0         elijah57@example.net  001-084-906-7849x73518    10/26/1945
# 1        bethany14@example.com       214.112.6044x4913     3/24/1910
# 2        bthompson@example.com            277.609.7938      7/2/1992
# ...

# %%
df1.head()
# Out:
#    Index          User Id First Name Last Name     Sex  \
# 0      1  88F7B33d2bcf9f5     Shelby   Terrell    Male
# 1      2  f90cD3E76f1A9b9    Phillip   Summers  Female
# 2      3  DbeAb8CcdfeFC2c   Kristine    Travis    Male
# 3      4  A31Bee3c201ef58    Yesenia  Martinez    Male
# 4      5  1bA7A3dc874da3c       Lori      Todd    Male
#
#                         Email                   Phone Date of birth  \
# 0        elijah57@example.net  001-084-906-7849x73518    10/26/1945
# 1       bethany14@example.com       214.112.6044x4913     3/24/1910
# 2       bthompson@example.com            277.609.7938      7/2/1992
# 3   kaitlinkaiser@example.com            584.094.6111      8/3/2017
# 4  buchananmanuel@example.net       689-207-3558x7233     12/1/1938
#
#            Unnamed: 8
# 0     Games developer
# 1                 NaN
# 2                 NaN
# 3   Market researcher
# 4  Veterinary surgeon

# %% [markdown]
# df1.dropn()

# %%
df1
# Out:
#     Index          User Id First Name  Last Name     Sex  \
# 0       1  88F7B33d2bcf9f5     Shelby    Terrell    Male
# 1       2  f90cD3E76f1A9b9    Phillip    Summers  Female
# 2       3  DbeAb8CcdfeFC2c   Kristine     Travis    Male
# 3       4  A31Bee3c201ef58    Yesenia   Martinez    Male
# 4       5  1bA7A3dc874da3c       Lori       Todd    Male
# ..    ...              ...        ...        ...     ...
# 95     96  5eFda7caAeB260E     Dennis     Barnes  Female
# 96     97  CCbFce93d3720bE      Steve  Patterson  Female
# 97     98  2fEc528aFAF0b69     Wesley       Bray    Male
# 98     99  Adc7ad9B6e4A1Fe     Summer   Oconnell  Female
# 99    100  b8D0aD3490FC7e1     Mariah    Bernard     NaN
#
#                          Email                   Phone Date of birth  \
# 0         elijah57@example.net  001-084-906-7849x73518    10/26/1945
# 1        bethany14@example.com       214.112.6044x4913     3/24/1910
# 2        bthompson@example.com            277.609.7938      7/2/1992
# ...

# %%
df1
# Out:
#     Index          User Id First Name  Last Name     Sex  \
# 0       1  88F7B33d2bcf9f5     Shelby    Terrell    Male
# 1       2  f90cD3E76f1A9b9    Phillip    Summers  Female
# 2       3  DbeAb8CcdfeFC2c   Kristine     Travis    Male
# 3       4  A31Bee3c201ef58    Yesenia   Martinez    Male
# 4       5  1bA7A3dc874da3c       Lori       Todd    Male
# ..    ...              ...        ...        ...     ...
# 95     96  5eFda7caAeB260E     Dennis     Barnes  Female
# 96     97  CCbFce93d3720bE      Steve  Patterson  Female
# 97     98  2fEc528aFAF0b69     Wesley       Bray    Male
# 98     99  Adc7ad9B6e4A1Fe     Summer   Oconnell  Female
# 99    100  b8D0aD3490FC7e1     Mariah    Bernard     NaN
#
#                          Email                   Phone Date of birth  \
# 0         elijah57@example.net  001-084-906-7849x73518    10/26/1945
# 1        bethany14@example.com       214.112.6044x4913     3/24/1910
# 2        bthompson@example.com            277.609.7938      7/2/1992
# ...

# %%
df1.fillna(0)
# Out:
#     Index          User Id First Name  Last Name     Sex  \
# 0       1  88F7B33d2bcf9f5     Shelby    Terrell    Male
# 1       2  f90cD3E76f1A9b9    Phillip    Summers  Female
# 2       3  DbeAb8CcdfeFC2c   Kristine     Travis    Male
# 3       4  A31Bee3c201ef58    Yesenia   Martinez    Male
# 4       5  1bA7A3dc874da3c       Lori       Todd    Male
# ..    ...              ...        ...        ...     ...
# 95     96  5eFda7caAeB260E     Dennis     Barnes  Female
# 96     97  CCbFce93d3720bE      Steve  Patterson  Female
# 97     98  2fEc528aFAF0b69     Wesley       Bray    Male
# 98     99  Adc7ad9B6e4A1Fe     Summer   Oconnell  Female
# 99    100  b8D0aD3490FC7e1     Mariah    Bernard       0
#
#                          Email                   Phone Date of birth  \
# 0         elijah57@example.net  001-084-906-7849x73518    10/26/1945
# 1        bethany14@example.com       214.112.6044x4913     3/24/1910
# 2        bthompson@example.com            277.609.7938      7/2/1992
# ...

# %%
# df.rename(columns={"First Name" : "FN" ,"Last Name": "LN" },inplace="false")

# %%
df.rename(columns={"First Name" : "FN" ,"Last Name": "LN" })
# Out:
#     Index          User Id        FN         LN     Sex  \
# 0       1  88F7B33d2bcf9f5    Shelby    Terrell    Male
# 1       2  f90cD3E76f1A9b9   Phillip    Summers  Female
# 2       3  DbeAb8CcdfeFC2c  Kristine     Travis    Male
# 3       4  A31Bee3c201ef58   Yesenia   Martinez    Male
# 4       5  1bA7A3dc874da3c      Lori       Todd    Male
# ..    ...              ...       ...        ...     ...
# 95     96  5eFda7caAeB260E    Dennis     Barnes  Female
# 96     97  CCbFce93d3720bE     Steve  Patterson  Female
# 97     98  2fEc528aFAF0b69    Wesley       Bray    Male
# 98     99  Adc7ad9B6e4A1Fe    Summer   Oconnell  Female
# 99    100  b8D0aD3490FC7e1    Mariah    Bernard    Male
#
#                          Email                   Phone Date of birth  \
# 0         elijah57@example.net  001-084-906-7849x73518    1945-10-26
# 1        bethany14@example.com       214.112.6044x4913    1910-03-24
# 2        bthompson@example.com            277.609.7938    1992-07-02
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Index          100 non-null    int64
#  1   User Id        100 non-null    object
#  2   FN             100 non-null    object
#  3   LN             100 non-null    object
#  4   Sex            100 non-null    object
#  5   Email          100 non-null    object
#  6   Phone          100 non-null    object
#  7   Date of birth  100 non-null    object
#  8   Job Title      100 non-null    object
# dtypes: int64(1), object(8)
# memory usage: 7.2+ KB

# %%
df["Phone"] = df["Phone"].astype(str)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Index          100 non-null    int64
#  1   User Id        100 non-null    object
#  2   FN             100 non-null    object
#  3   LN             100 non-null    object
#  4   Sex            100 non-null    object
#  5   Email          100 non-null    object
#  6   Phone          100 non-null    object
#  7   Date of birth  100 non-null    object
#  8   Job Title      100 non-null    object
# dtypes: int64(1), object(8)
# memory usage: 7.2+ KB

# %%
df["Phone"][0]
# Out:
# '001-084-906-7849x73518'

# %%
len(df)
# Out:
# 100

# %%
df["Zero"]= [0 for i in range(len(df))]

# %%
df
# Out:
#     Index          User Id        FN         LN     Sex  \
# 0       1  88F7B33d2bcf9f5    Shelby    Terrell    Male
# 1       2  f90cD3E76f1A9b9   Phillip    Summers  Female
# 2       3  DbeAb8CcdfeFC2c  Kristine     Travis    Male
# 3       4  A31Bee3c201ef58   Yesenia   Martinez    Male
# 4       5  1bA7A3dc874da3c      Lori       Todd    Male
# ..    ...              ...       ...        ...     ...
# 95     96  5eFda7caAeB260E    Dennis     Barnes  Female
# 96     97  CCbFce93d3720bE     Steve  Patterson  Female
# 97     98  2fEc528aFAF0b69    Wesley       Bray    Male
# 98     99  Adc7ad9B6e4A1Fe    Summer   Oconnell  Female
# 99    100  b8D0aD3490FC7e1    Mariah    Bernard    Male
#
#                          Email                   Phone Date of birth  \
# 0         elijah57@example.net  001-084-906-7849x73518    1945-10-26
# 1        bethany14@example.com       214.112.6044x4913    1910-03-24
# 2        bthompson@example.com            277.609.7938    1992-07-02
# ...

# %%
def fx(a):
        return a*a
df["Index + 1"]= df["Index"].apply(fx)

# %%
df
# Out:
#     Index          User Id        FN         LN     Sex  \
# 0       1  88F7B33d2bcf9f5    Shelby    Terrell    Male
# 1       2  f90cD3E76f1A9b9   Phillip    Summers  Female
# 2       3  DbeAb8CcdfeFC2c  Kristine     Travis    Male
# 3       4  A31Bee3c201ef58   Yesenia   Martinez    Male
# 4       5  1bA7A3dc874da3c      Lori       Todd    Male
# ..    ...              ...       ...        ...     ...
# 95     96  5eFda7caAeB260E    Dennis     Barnes  Female
# 96     97  CCbFce93d3720bE     Steve  Patterson  Female
# 97     98  2fEc528aFAF0b69    Wesley       Bray    Male
# 98     99  Adc7ad9B6e4A1Fe    Summer   Oconnell  Female
# 99    100  b8D0aD3490FC7e1    Mariah    Bernard    Male
#
#                          Email                   Phone Date of birth  \
# 0         elijah57@example.net  001-084-906-7849x73518    1945-10-26
# 1        bethany14@example.com       214.112.6044x4913    1910-03-24
# 2        bthompson@example.com            277.609.7938    1992-07-02
# ...

# %%
df.to_csv("export.csv")

# %%
df2=pd.DataFrame(
    {
        "name":["sameer","asif","ammad","talib","imam"], "marks":[100,26,90,41,50]
    }
)

# %%
df2
# Out:
#      name  marks
# 0  sameer    100
# 1    asif     26
# 2   ammad     90
# 3   talib     41
# 4    imam     50

# %%
df3=pd.DataFrame(
    {
        "name":["furqan","asif","ammad","aman"], "marks":[10,26,99,41]
    }
)

# %%
pd.concat([df2,df3])
# Out:
#      name  marks
# 0  sameer    100
# 1    asif     26
# 2   ammad     90
# 3   talib     41
# 4    imam     50
# 0  furqan     10
# 1    asif     26
# 2   ammad     99
# 3    aman     41
